# %%
import matplotlib.font_manager as fm
for font in fm.fontManager.ttflist:
    if 'Hei' in font.name or 'Song' in font.name or 'Kai' in font.name:
        print(f"字体名: {font.name}")
# Out:
# 字体名: FangSong
# 字体名: KaiTi
# 字体名: Microsoft JhengHei
# 字体名: Microsoft JhengHei
# 字体名: Microsoft JhengHei
# 字体名: Microsoft YaHei
# 字体名: Microsoft YaHei
# 字体名: STSong
# 字体名: STKaiti
# 字体名: SimHei
# 字体名: Microsoft YaHei
